# %% [markdown]
# <a href="https://colab.research.google.com/github/leegyuhi/oooooooooooooh/blob/master/SineFunction_Animation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation, rc

# %%
fig, ax = plt.subplots()

ax.set_xlim(( 0, 1))
ax.set_ylim((-1.0, 1.0))
ax.set_xticks([])
ax.set_yticks([])
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
ax.grid()

line, = ax.plot([], [], lw=2, label=r"$y=sin(2\pi x)$")
ax.legend()

# %%
def init():
    line.set_data([], [])
    return (line,)
def animate(i):
    x = np.linspace(0, 1, 1000)
    y = np.sin(2 * np.pi*x) * np.exp(-0.1 * i)
    line.set_data(x, y)
    return (line,)

# %%
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=100, interval=25, blit=True)

# %%
rc('animation', html='html5')
anim
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>
